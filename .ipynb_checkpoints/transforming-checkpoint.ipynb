# %%
import warnings
warnings.simplefilter(action = "ignore", category = RuntimeWarning)

td_props = [('font-size', '20px')]
th_props = [('font-size', '20px')]
styles = [dict(selector="td", props=td_props), dict(selector="th", props=th_props)]

# %% [markdown]
# # Transformando dados
#
#
# #### gabriela cavalcante
#
# #### francisco campos
#
# #### nicolas lima
#
# #### valmir correa

# %% [markdown]
# # por que transformar os dados?

# %% [markdown]
# # escalando os valores
#
# - Normalizar
#
# - Padronizar (*Standardize*)

# %% [markdown]
# This is the dataset used in the second chapter of Aurélien Géron's recent book 'Hands-On Machine learning with Scikit-Learn and TensorFlow'. It serves as an excellent introduction to implementing machine learning algorithms because it requires rudimentary data cleaning, has an easily understandable list of variables and sits at an optimal size between being to toyish and too cumbersome
#
# The data contains information from the 1990 California census. So although it may not help you with predicting current housing prices like the Zillow Zestimate dataset, it does provide an accessible introductory dataset for teaching people about the basics of machine learning.

# %%
import pandas as pd
import numpy as np

# dados contendo informações do censo de 1990 da California
housing = pd.read_csv("https://raw.githubusercontent.com/gabicavalcante/data-transform/master/housing.csv", sep=",")
housing.head().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_920b9010_cdef_11e9_8a40_a0999b155487 td {
#           font-size: 20px;
#     }    #T_920b9010_cdef_11e9_8a40_a0999b155487 th {
#           font-size: 20px;
#     }</style><table id="T_920b9010_cdef_11e9_8a40_a0999b155487" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >longitude</th>        <th class="col_heading level0 col1" >latitude</th>        <th class="col_heading level0 col2" >housing_median_age</th>        <th class="col_heading level0 col3" >total_rooms</th>        <th class="col_heading level0 col4" >total_bedrooms</th>        <th class="col_heading level0 col5" >population</th>        <th class="col_heading level0 col6" >households</th>        <th class="col_heading level0 col7" >median_income</th>        <th class="col_heading level0 col8" >median_house_value</th>        <th class="col_heading level0 col9" >ocean_proximity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_920b9010_cdef_11e9_8a40_a0999b155487level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col0" class="data row0 col0" >-122.23</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col1" class="data row0 col1" >37.88</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col2" class="data row0 col2" >41</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col3" class="data row0 col3" >880</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col4" class="data row0 col4" >129</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col5" class="data row0 col5" >322</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col6" class="data row0 col6" >126</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col7" class="data row0 col7" >8.3252</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col8" class="data row0 col8" >452600</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row0_col9" class="data row0 col9" >NEAR BAY</td>
#             </tr>
#             <tr>
#                         <th id="T_920b9010_cdef_11e9_8a40_a0999b155487level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col0" class="data row1 col0" >-122.22</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col1" class="data row1 col1" >37.86</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col2" class="data row1 col2" >21</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col3" class="data row1 col3" >7099</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col4" class="data row1 col4" >1106</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col5" class="data row1 col5" >2401</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col6" class="data row1 col6" >1138</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col7" class="data row1 col7" >8.3014</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col8" class="data row1 col8" >358500</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row1_col9" class="data row1 col9" >NEAR BAY</td>
#             </tr>
#             <tr>
#                         <th id="T_920b9010_cdef_11e9_8a40_a0999b155487level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col0" class="data row2 col0" >-122.24</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col1" class="data row2 col1" >37.85</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col2" class="data row2 col2" >52</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col3" class="data row2 col3" >1467</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col4" class="data row2 col4" >190</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col5" class="data row2 col5" >496</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col6" class="data row2 col6" >177</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col7" class="data row2 col7" >7.2574</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col8" class="data row2 col8" >352100</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row2_col9" class="data row2 col9" >NEAR BAY</td>
#             </tr>
#             <tr>
#                         <th id="T_920b9010_cdef_11e9_8a40_a0999b155487level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col0" class="data row3 col0" >-122.25</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col1" class="data row3 col1" >37.85</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col2" class="data row3 col2" >52</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col3" class="data row3 col3" >1274</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col4" class="data row3 col4" >235</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col5" class="data row3 col5" >558</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col6" class="data row3 col6" >219</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col7" class="data row3 col7" >5.6431</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col8" class="data row3 col8" >341300</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row3_col9" class="data row3 col9" >NEAR BAY</td>
#             </tr>
#             <tr>
#                         <th id="T_920b9010_cdef_11e9_8a40_a0999b155487level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col0" class="data row4 col0" >-122.25</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col1" class="data row4 col1" >37.85</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col2" class="data row4 col2" >52</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col3" class="data row4 col3" >1627</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col4" class="data row4 col4" >280</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col5" class="data row4 col5" >565</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col6" class="data row4 col6" >259</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col7" class="data row4 col7" >3.8462</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col8" class="data row4 col8" >342200</td>
#                         <td id="T_920b9010_cdef_11e9_8a40_a0999b155487row4_col9" class="data row4 col9" >NEAR BAY</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # pra que normalizar os dados?

# %% [markdown]
# ### algoritmos enxergam números, mas não entendem o que eles significam

# %%
housing[['housing_median_age', 'median_house_value']].head().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_920e8694_cdef_11e9_8a40_a0999b155487 td {
#           font-size: 20px;
#     }    #T_920e8694_cdef_11e9_8a40_a0999b155487 th {
#           font-size: 20px;
#     }</style><table id="T_920e8694_cdef_11e9_8a40_a0999b155487" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >housing_median_age</th>        <th class="col_heading level0 col1" >median_house_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_920e8694_cdef_11e9_8a40_a0999b155487level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row0_col0" class="data row0 col0" >41</td>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row0_col1" class="data row0 col1" >452600</td>
#             </tr>
#             <tr>
#                         <th id="T_920e8694_cdef_11e9_8a40_a0999b155487level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row1_col0" class="data row1 col0" >21</td>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row1_col1" class="data row1 col1" >358500</td>
#             </tr>
#             <tr>
#                         <th id="T_920e8694_cdef_11e9_8a40_a0999b155487level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row2_col0" class="data row2 col0" >52</td>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row2_col1" class="data row2 col1" >352100</td>
#             </tr>
#             <tr>
#                         <th id="T_920e8694_cdef_11e9_8a40_a0999b155487level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row3_col0" class="data row3 col0" >52</td>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row3_col1" class="data row3 col1" >341300</td>
#             </tr>
#             <tr>
#                         <th id="T_920e8694_cdef_11e9_8a40_a0999b155487level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row4_col0" class="data row4 col0" >52</td>
#                         <td id="T_920e8694_cdef_11e9_8a40_a0999b155487row4_col1" class="data row4 col1" >342200</td>
#             </tr>
#     </tbody></table>

# %%
import matplotlib.pyplot as plt


fig, axs = plt.subplots(1, 2, figsize=(25, 10))
# quartos
axs[0].hist(housing.total_bedrooms, bins=500)
# renda média
axs[1].hist(housing.median_income, bins=500)

plt.show()

# %%
housing.total_bedrooms.describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
# households: número total de famílias por quarteirão
housing['avg_bedrooms'] = housing['total_bedrooms']/housing['households'] 
housing[['avg_bedrooms']].head().style.set_table_styles(styles)
# Out:
# <style  type="text/css" >
#     #T_939f9c14_cdef_11e9_8a40_a0999b155487 td {
#           font-size: 20px;
#     }    #T_939f9c14_cdef_11e9_8a40_a0999b155487 th {
#           font-size: 20px;
#     }</style><table id="T_939f9c14_cdef_11e9_8a40_a0999b155487" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >avg_bedrooms</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_939f9c14_cdef_11e9_8a40_a0999b155487level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_939f9c14_cdef_11e9_8a40_a0999b155487row0_col0" class="data row0 col0" >1.02381</td>
#             </tr>
#             <tr>
#                         <th id="T_939f9c14_cdef_11e9_8a40_a0999b155487level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_939f9c14_cdef_11e9_8a40_a0999b155487row1_col0" class="data row1 col0" >0.97188</td>
#             </tr>
#             <tr>
#                         <th id="T_939f9c14_cdef_11e9_8a40_a0999b155487level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_939f9c14_cdef_11e9_8a40_a0999b155487row2_col0" class="data row2 col0" >1.07345</td>
#             </tr>
#             <tr>
#                         <th id="T_939f9c14_cdef_11e9_8a40_a0999b155487level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_939f9c14_cdef_11e9_8a40_a0999b155487row3_col0" class="data row3 col0" >1.07306</td>
#             </tr>
#             <tr>
#                         <th id="T_939f9c14_cdef_11e9_8a40_a0999b155487level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_939f9c14_cdef_11e9_8a40_a0999b155487row4_col0" class="data row4 col0" >1.08108</td>
#             </tr>
#     </tbody></table>

# %%
housing.avg_bedrooms.describe()
# Out:
# count    20433.000000
# mean         1.097062
# std          0.476104
# min          0.333333
# 25%          1.006029
# 50%          1.048889
# 75%          1.099631
# max         34.066667
# Name: avg_bedrooms, dtype: float64

# %%
def normalize(column):
    upper = column.max()
    lower = column.min()
    y = (column - lower)/(upper - lower)
    return y
  
total_bedrooms_normalized = normalize(housing.total_bedrooms)

fig, ax = plt.subplots(figsize=(15,8))
plt.hist(total_bedrooms_normalized)
plt.show()

# %%
import numpy as np 

# média igual a 0 e um desvio padrão igual a 1
def standardize(column):  
    z = (column - column.mean())/np.std(column)
    return z
  
total_bedrooms_standardized = standardize(housing.total_bedrooms)

fig, ax = plt.subplots(figsize=(15,7))
plt.hist(total_bedrooms_standardized)
plt.show()

# %% [markdown]
# - Se a distribuição não é Gaussiana ou o desvio padrão é muito pequeno, normalizar os dados é uma escolha a ser tomada.

# %% [markdown]
# # usando log nos dados

# %% [markdown]
# Muitas variáveis na área de biologia têm distribuição lognormal. Então, analisar não a variável coletada, mas a variável transformada, isto é, o logaritmo (decimal ou neperiano) dessa variável, ajuda a estabilizar a variância e tornar a distribuição normal. Mas como se reconhece a necessidade da transformação logarítmica?
# Se a variância dos grupos cresce com a média, é razoável optar pela variável transformada para a análise. A explicação é a de que, se a variável que você estuda é resultante de vários fatores que se multiplicam, então essa variável tem distribuição lognormal. Um exemplo é a altura das árvores de um pomar. A altura de uma árvore é afetada pelo solo, quantidade de água, de luz solar, de ventos etc. Então a variável altura das árvores de um pomar tem distribuição lognormal. Também deve ter distribuição lognormal o tempo de sobrevivência de bactérias em desinfetantes, o peso e a pressão sanguínea das pessoas.

# %%
import numpy as np
 
total_bedrooms_log = np.log(housing.total_bedrooms + 1)

fig, axs = plt.subplots(1, 2, figsize=(25, 10))
# quartos
axs[0].hist(housing.total_bedrooms)
# renda média
axs[1].hist(total_bedrooms_log)

plt.show()

# %%
plt.scatter(housing.total_bedrooms, housing.population, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
population_log = np.log(housing.population + 1)

fig, axs = plt.subplots(1, 2, figsize=(25, 10))
# quartos
axs[0].scatter(total_bedrooms_log, housing.population, alpha=0.5)
# renda média
axs[1].scatter(housing.total_bedrooms, population_log, alpha=0.5)

plt.show()

# %% [markdown]
# # quantis

# %%
print('25% : {}'.format(housing.median_house_value.quantile(q=0.25)))
print('25% : {}'.format(housing.median_house_value.quantile()))
print('75% : {}'.format(housing.median_house_value.quantile(q=0.75)))
print(housing.median_house_value.describe())
# Out:
# 25% : 119600.0
# 25% : 179700.0
# 75% : 264725.0
# count     20640.000000
# mean     206855.816909
# std      115395.615874
# min       14999.000000
# 25%      119600.000000
# 50%      179700.000000
# 75%      264725.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
A = pd.Series([1.2, 2.4, 4.5, 7.8, 8, 9.4, 9.56, 11.34, 12, 18]) 

def calc_quantile(N, k, q):
    """ N: tamanho da amostra
        k: k-ésimo quartil
        q: quantidades de quantis que dividiremos nossa amostra
    """
    return (N+1)*(k/q) 
 
posicao = calc_quantile(len(A), 2, 4)
print('posição encontrada: %s' %posicao)

# verificar se o valor nao é inteiro
if not posicao.is_integer():
    anterior = A[int(posicao) - 1]
    posterior = A[int(posicao)]
    media = (anterior + posterior) / 2
    
    print('valor da anterior: %s' %anterior)
    print('valor da seguinte: %s' %posterior)
    print('média: %s (%s)' %(media, int(media))) 
    posicao = int(media)
else:
    posicao -= 1

print('valor do primeiro quartil: %s' %A[posicao - 1])
print('50% : {}'.format(A.quantile(q=0.50)))
# Out:
# posição encontrada: 5.5
# valor da anterior: 8.0
# valor da seguinte: 9.4
# média: 8.7 (8)
# valor do primeiro quartil: 11.34
# 50% : 8.7

# %% [markdown]
# #  intervalo de confiança

# %% [markdown]
# Intervalo de confiança (IC) é um intervalo estimado de um parâmetro de interesse de uma população. Em vez de estimar o parâmetro por um único valor, é dado um intervalo de estimativas prováveis

# %%
sample = housing.median_house_value.sample(n=100, random_state=1)

# %%
import numpy as np, scipy.stats as st

st.t.interval(0.95, len(sample)-1, loc=np.mean(sample), scale=st.sem(sample))
# Out:
# (166488.57823101827, 206577.42176898173)

# %%
np.mean(housing.median_house_value)
# Out:
# 206855.81690891474

# %%
import statsmodels.stats.api as sms

sms.DescrStatsW(sample).tconfint_mean()
# Out:
# (166488.57823101824, 206577.42176898176)

# %% [markdown]
# # dúvidas?
